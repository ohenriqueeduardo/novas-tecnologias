# %% [markdown]
# # Exercício 1 - Cadastro e análise simples de veículos
#
# Uma concessionária deseja registrar alguns veículos disponíveis para venda.
# Crie um programa em Python que crie uma lista de veículos.
#
# Cada veículo deve ser representado por um dicionário contendo:
# - marca
# - modelo
# - preço
# - ano
#
# Exemplo de estrutura esperada:
#
# ```
# veiculo = {
#     "marca": "Toyota",
#     "modelo": "Corolla",
#     "preco": 120000,
#     "ano": 2022
# }
# ```
#
# O programa deve:
#
# - Adicionar pelo *menos 5 veículos* à lista.
# - Exibir todos os veículos cadastrados.
# - Calcular o *preço médio dos veículos*.
# - Mostrar quais *veículos custam acima da média*.
#
# ### Saída esperada (exemplo)
# ```
# Preço médio dos veículos: 85000
# Veículos acima da média:
# Honda Civic - 110000
# Toyota Corolla - 120000
# ```

# %%
class Veiculo:

   def __init__(self, marca, modelo, preco, ano):
      self.marca = marca
      self.modelo = modelo
      self.preco = preco
      self.ano = ano

   def imprimir(self):
      print(f"Marca: {self.marca}")
      print(f"Modelo: {self.modelo}")
      print(f"Preço: {self.preco:,}")
      print(f"Ano: {self.ano}\n")

# %%
# Solução do exercício 1

veiculos = []
qtd_veiculos = 5

for i in range(5):
   marca = input("Marca: ")
   modelo = input("Modelo: ")
   preco = float(input("Preço: "))
   ano = int(input("Ano: "))
   veiculo = Veiculo(marca, modelo, preco, ano)
   veiculos.append(veiculo)

# %%
soma_preco_veiculos = 0

for v in veiculos:
   v.imprimir()
   soma_preco_veiculos += v.preco
preco_medio_veiculos = soma_preco_veiculos / qtd_veiculos

print(f"\nValor total dos veículos: R${soma_preco_veiculos:,}")
print(f"\nPreço médio dos veículos: R${preco_medio_veiculos:,}")

print("\nVeículos acima da média")
for v in veiculos:
   if v.preco > preco_medio_veiculos:
      print(f"{v.marca} {v.modelo} - {v.preco:,}")
# Out:
# Marca: Nissan
# Modelo: Skyline R34
# Preço: 1,800,000.0
# Ano: 1999
#
# Marca: Dodge
# Modelo: Challenger SRT Hellcat
# Preço: 2,850,000.0
# Ano: 2020
#
# Marca: Ferrari
# Modelo: F 40 Competizione
# Preço: 40,000,000.0
# Ano: 1998
#
# Marca: RAM
# Modelo: Rebel 3500
# Preço: 3,890,000.0
# Ano: 2023
#
# Marca: Porsche
# Modelo: 911 GT3 RS
# Preço: 2,850,000.0
# Ano: 2023
#
#
# Valor total dos veículos: R$51,390,000.0
#
# Preço médio dos veículos: R$10,278,000.0
#
# Veículos acima da média
# Ferrari F 40 Competizione - 40,000,000.0

# %% [markdown]
# # Exercício 2 - Sistema simples de financiamento
#
# Uma concessionária oferece financiamento de veículos.
#
# Crie uma função chamada:
#
# ```
# calcular_financiamento(preco, entrada, parcelas)
# ```
#
# A função deve calcular o valor financiado.
#
# ```
# valor_financiado = preco - entrada
# ```
#
# Considerar uma taxa de juros simples de 1.5% ao mês.
#
# Fórmula simplificada:
# ```
# valor_total = valor_financiado * (1 + taxa * parcelas)
# parcela = valor_total / parcelas
# ```
# A função deve retornar o valor da parcela.
#
#
# ### Crie um programa que:
#
# - Defina o preço de um veículo
# - Pergunte ao usuário: valor de entrada e número de parcelas
# - Use a função para calcular o financiamento
# - Exiba o valor da parcela
# - Impedir parcelas maiores que 72 meses
# - Mostrar uma mensagem caso isso ocorra (Número máximo de parcelas é 72.)
#
# ### Exemplo de saída
#
# ```
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 1785.50
# ```

# %%
# Solução do exercício 2

def calcular_financiamento(preço, entrada, parcelas):
    taxa = 0.015
    valor_financiado = preço - entrada

    valor_total = valor_financiado * (1 + taxa * parcelas)
    parcela = valor_total / parcelas

    return parcela


preco_veiculo = 80000

entrada = int(input("Insira o valor da entrada: "))
n_parcelas = int(input("Insira o n° de parcelas: "))

if n_parcelas < 72:
    print(f"O valor da parcela mensal é de: R${calcular_financiamento(preco_veiculo, entrada, n_parcelas):.2f}")
else:
    print("O número de parcelas é invalido para este financiamento")
# Out:
# Insira o valor da entrada:  25000
# Insira o n° de parcelas:  38
# O valor da parcela mensal é de: R$2272.37
